# %% [markdown]
# # Source
#
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://medium.com/@sugath.mudali/fundamental-analysis-for-ranking-stocks-with-python-api-0bf44cffd6da"><img src="https://cdn.icon-icons.com/icons2/2997/PNG/32/medium_logo_icon_187624.png" />Watch in Medium</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Mykrass/stocks-analysis-colab.git"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
# </table>

# %%
# !git clone https://github.com/Mykrass/stocks-analysis-colab.git
# Out:
# Cloning into 'stocks-analysis-colab'...
# remote: Enumerating objects: 301, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 301 (delta 5), reused 0 (delta 0), pack-reused 288
# Receiving objects: 100% (301/301), 2.06 MiB | 11.74 MiB/s, done.
# Resolving deltas: 100% (149/149), done.

# %%
# !ls -GFlash --color ./stocks-analysis-colab/
# Out:
# total 6.6M
# 4.0K drwxr-xr-x 8 root 4.0K Jan 26 16:13 ./
# 4.0K drwxr-xr-x 1 root 4.0K Jan 26 16:13 ../
# 4.0K drwxr-xr-x 5 root 4.0K Jan 26 16:13 asx/
#  12K -rw-r--r-- 1 root  11K Jan 26 16:13 av_dcf.ipynb
#  20K -rw-r--r-- 1 root  20K Jan 26 16:13 av_insert_earnings.ipynb
#  28K -rw-r--r-- 1 root  28K Jan 26 16:13 av_insert_income_statements.ipynb
# 8.0K -rw-r--r-- 1 root 6.6K Jan 26 16:13 av_wacc.ipynb
# 4.0K drwxr-xr-x 2 root 4.0K Jan 26 16:13 config/
# 4.0K drwxr-xr-x 5 root 4.0K Jan 26 16:13 dasboard/
# 4.0K drwxr-xr-x 2 root 4.0K Jan 26 16:13 data/
#  88K -rw-r--r-- 1 root  88K Jan 26 16:13 fh_analyst_trends.ipynb
# 4.0K drwxr-xr-x 2 root 4.0K Jan 26 16:13 fundamental_analysis/
# 4.0K drwxr-xr-x 8 root 4.0K Jan 26 16:13 .git/
# 4.0K -rw-r--r-- 1 root 3.1K Jan 26 16:13 .gitignore
# 4.0K -rw-r--r-- 1 root 1.1K Jan 26 16:13 LICENSE
# 8.0K -rw-r--r-- 1 root 4.7K Jan 26 16:13 README.md
# 116K -rw-r--r-- 1 root 113K Jan 26 16:13 yf_dashboard.ipynb
#  12K -rw-r--r-- 1 root 8.6K Jan 26 16:13 yf_dcf.ipynb
#  12K -rw-r--r-- 1 root  11K Jan 26 16:13 yf_dcf_v2.ipynb
#  20K -rw-r--r-- 1 root  20K Jan 26 16:13 yf_stock_picker_p1.ipynb
#  52K -rw-r--r-- 1 root  50K Jan 26 16:13 yf_stock_picker_p2.ipynb
#  64K -rw-r--r-- 1 root  64K Jan 26 16:13 yf_stock_screener.ipynb
# 1.2M -rw-r--r-- 1 root 1.2M Jan 26 16:13 yf_ta_part1.ipynb
# 1.4M -rw-r--r-- 1 root 1.4M Jan 26 16:13 yf_ta_part2.ipynb
# 3.6M -rw-r--r-- 1 root 3.6M Jan 26 16:13 yf_valuation.ipynb
# 8.0K -rw-r--r-- 1 root 6.0K Jan 26 16:13 yf_wacc.ipynb

# %%
# !ls -GFlash --color ./stocks-analysis-colab/fundamental_analysis/
# Out:
# total 136K
# 4.0K drwxr-xr-x 2 root 4.0K Jan 26 16:13 ./
# 4.0K drwxr-xr-x 8 root 4.0K Jan 26 16:13 ../
# 4.0K -rw-r--r-- 1 root  339 Jan 26 16:13 README.md
# 4.0K -rw-r--r-- 1 root  474 Jan 26 16:13 save_info.py
# 4.0K -rw-r--r-- 1 root 2.8K Jan 26 16:13 yfinance3.py
# 116K -rw-r--r-- 1 root 115K Jan 26 16:13 yf_stock_FA.ipynb

# %%
# !cat ./stocks-analysis-colab/fundamental_analysis/yfinance3.py
# Out:
# import requests, urllib
#
# class YFinance3:
#     user_agent_key = "User-Agent"
#     user_agent_value = ("Mozilla/5.0 (Windows NT 6.1; Win64; x64) "
#                         "AppleWebKit/537.36 (KHTML, like Gecko) "
#                         "Chrome/58.0.3029.110 Safari/537.36")
#
#     def __init__(self, ticker):
#         self.yahoo_ticker = ticker
#
#     def __str__(self):
#         return self.yahoo_ticker
#
#     def _get_yahoo_cookie(self):
#         cookie = None
#
#         headers = {self.user_agent_key: self.user_agent_value}
#         response = requests.get("https://fc.yahoo.com",
#                                 headers=headers,
#                                 allow_redirects=True)
#
#         if not response.cookies:
#             raise Exception("Failed to obtain Yahoo auth cookie.")
#
#         cookie = list(response.cookies)[0]
#
#         return cookie
#
#     def _get_yahoo_crumb(self, cookie):
#         crumb = None
#
#         headers = {self.user_agent_key: self.user_agent_value}
#
#         crumb_response = requests.get(
#             "https://query1.finance.yahoo.com/v1/test/getcrumb",
#             headers=headers,
#             cookies={cookie.name: cookie.value},
#             allow_redirects=True,
#         )
#         crumb = crumb_response.text
#
#         if crumb is None:
#             raise Exception("Failed to retrieve Yahoo crumb.")
#
#         return crumb
#
#     @property
#     def info(self):
#         # Yahoo modules doc informations :
#         # https://cryptocointracker.com/yahoo-finance/yahoo-finance-api
#         cookie = self._get_yahoo_cookie()
#         crumb = self._get_yahoo_crumb(cookie)
#         info = {}
#         ret = {}
#
#         headers = {self.user_agent_key: self.user_agent_value}
#
#         yahoo_modules = ("financialData,"
#                          "quoteType,"
#                          "defaultKeyStatistics,"
#                          "assetProfile,"
#                          "summaryDetail")
#
#         url = ("https://query1.finance.yahoo.com/v10/finance/"
#                f"quoteSummary/{self.yahoo_ticker}"
#                f"?modules={urllib.parse.quote_plus(yahoo_modules)}"
#                f"&ssl=true&crumb={urllib.parse.quote_plus(crumb)}")
#
#         info_response = requests.get(url,
#                                      headers=headers,
#                                      cookies={cookie.name: cookie.value},
#                                      allow_redirects=True)
#
#         info = info_response.json()
#         info = info['quoteSummary']['result'][0]
#
#         for mainKeys in info.keys():
#             for key in info[mainKeys].keys():
#                 if isinstance(info[mainKeys][key], dict):
#                     try:
#                         ret[key] = info[mainKeys][key]['raw']
#                     except (KeyError, TypeError):
#                         pass
#                 else:
#                     ret[key] = info[mainKeys][key]
#
#         return ret

# %%
# !cat ./stocks-analysis-colab/fundamental_analysis/save_info.py
# Out:
# from yfinance3 import YFinance3
# import json
#
# SYMBOLS = ['INTU','CDNS','WDAY','ROP','TEAM','ADSK','DDOG','ANSS','ZM','PTC',\
#            'BSY','GRAB','SSNC','APP','AZPN','MANH','ZI','NICE']
#
# for symbol in SYMBOLS:
#     data = YFinance3(symbol)
#     file_name = f'out/info/{symbol}.json'
#     # Use a context manager to open the file and write the JSON data to it
#     with open(file_name, 'w') as file:
#         json.dump(data.info, file)
#     print('saved to {}'.format(file_name))

# %% [markdown]
# ## Imports

# %%
# Import libraries
import json
import pandas as pd
import sys
import os
import warnings
import matplotlib.pyplot as plt

#
#from src.data_preparation_automl_regression import *
sys.path.append('/content/stocks-analysis-colab/fundamental_analysis/')
from  yfinance3 import *
#from  save_info import *
# !rm -rf out/info/
# !mkdir -p out/info/
from  save_info import *

# Set options for displaying dataframes and figures
pd.set_option('display.max_columns', None)
warnings.filterwarnings("ignore", category=FutureWarning)
pd.options.mode.chained_assignment = None
# Out:
# saved to out/info/INTU.json
# saved to out/info/CDNS.json
# saved to out/info/WDAY.json
# saved to out/info/ROP.json
# saved to out/info/TEAM.json
# saved to out/info/ADSK.json
# saved to out/info/DDOG.json
# saved to out/info/ANSS.json
# saved to out/info/ZM.json
# saved to out/info/PTC.json
# saved to out/info/BSY.json
# saved to out/info/GRAB.json
# saved to out/info/SSNC.json
# saved to out/info/APP.json
# saved to out/info/AZPN.json
# saved to out/info/MANH.json
# saved to out/info/ZI.json
# saved to out/info/NICE.json

# %% [markdown]
# ## Configuration

# %%
# List of stock symbols we need to run fundamental analysis on - any symbol added here must have the json file
# containing stock info from YF
SYMBOLS = ['INTU','CDNS','WDAY','ROP','TEAM','ADSK','DDOG','ANSS','ZM','PTC',\
           'BSY','GRAB','SSNC','APP','AZPN','MANH','ZI','NICE']

# Path to read stock data from YF
#DATA_PATH = '/home/sugath/poc/stocks_yf/out/info'
DATA_PATH = '/content/out/info'

# Dictionary to collect data to create a DF later
data = {
    'Symbol': [],
    'Name': [],
    'Industry': [],
    'EPS (fwd)': [],
    'P/E (fwd)': [],
    'PEG': [],
    'FCFY' : [],
    'PB': [],
    'ROE' : [],
    'P/S (trail)': [],
    'DPR' : [],
    'DY' : [],
    'CR' : [],
    'Beta': [],
    'Price': [],
    '52w Low': [],
    '52w High': []
    }

# %% [markdown]
# ## Loads data from json files

# %%
def load_data(json_data):
    data['Symbol'].append(json_data['symbol'])
    data['Name'].append(json_data['longName'])
    data['Industry'].append(json_data['industry'])
    data['Price'].append(json_data['currentPrice'])

    # Could be that some indicators are not available; use NaN if this is the case

    if 'forwardEps' in json_data:
        data['EPS (fwd)'].append(json_data['forwardEps'])
    else:
        data['EPS (fwd)'].append(np.nan)

    if 'forwardPE' in json_data:
        data['P/E (fwd)'].append(json_data['forwardPE'])
    else:
        data['P/E (fwd)'].append(np.nan)

    if 'pegRatio' in json_data:
        data['PEG'].append(json_data['pegRatio'])
    else:
        data['PEG'].append(np.nan)

    if ('freeCashflow' in json_data) and ('marketCap' in json_data):
        fcfy = (json_data['freeCashflow']/json_data['marketCap']) * 100
        data['FCFY'].append(round(fcfy, 2))
    else:
        data['FCFY'].append(np.nan)

    if 'priceToBook' in json_data:
        data['PB'].append(json_data['priceToBook'])
    else:
        data['PB'].append(np.nan)

    if 'returnOnEquity' in json_data:
        data['ROE'].append(json_data['returnOnEquity'])
    else:
        data['ROE'].append(np.nan)

    if 'priceToSalesTrailing12Months' in json_data:
        data['P/S (trail)'].append(json_data['priceToSalesTrailing12Months'])
    else:
        data['P/S (trail)'].append(np.nan)

    data['DPR'].append(json_data['payoutRatio'] * 100)

    if 'dividendYield' in json_data:
        data['DY'].append(json_data['dividendYield'])
    else:
        data['DY'].append(0.0)

    if 'beta' in json_data:
        data['Beta'].append(json_data['beta'])
    else:
        data['Beta'].append(np.nan)

    if 'currentRatio' in json_data:
        data['CR'].append(json_data['currentRatio'])
    else:
        data['CR'].append(np.nan)

    if 'fiftyTwoWeekLow' in json_data:
        data['52w Low'].append(json_data['fiftyTwoWeekLow'])
    else:
        data['52w Low'].append(np.nan)

    if 'fiftyTwoWeekHigh' in json_data:
        data['52w High'].append(json_data['fiftyTwoWeekHigh'])
    else:
        data['52w High'].append(np.nan)

# %% [markdown]
# ## Loads stock data from json files

# %%
for symbol in SYMBOLS:
    # Specify the full path to load JSON data
    file_name = f'{DATA_PATH}/{symbol}.json'
    try:
        # Open the file in read mode
        with open(file_name, 'r') as file:
            # Use json.load() to parse the JSON data from the file
            load_data(json.load(file))
    except FileNotFoundError:
        print(f"File '{file_name}' not found.")
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON data: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")

# %% [markdown]
# ## Create DF

# %%
# Create a DF using the dictionary
df = pd.DataFrame(data)

# Save any stocks with NaN values
df_exceptions = df[df.isna().any(axis=1)]

# Remove any stocks with NaN values
df=df.dropna()

# Reset index after dropping rows with NaN values
df.reset_index(drop=True, inplace=True)

# Add 52 week price range
df['52w Range'] = ((df['Price'] - df['52w Low'])/(df['52w High'] - df['52w Low']))*100

df_exceptions
# Out:
# Empty DataFrame
# Columns: [Symbol, Name, Industry, EPS (fwd), P/E (fwd), PEG, FCFY, PB, ROE, P/S (trail), DPR, DY, CR, Beta, Price, 52w Low, 52w High]
# Index: []

# %% [markdown]
# ## Adds styles to DF

# %%
def make_pretty(styler):
    # Column formatting
    styler.format({'EPS (fwd)': '${:.2f}', 'P/E (fwd)': '{:.2f}', 'PEG': '{:.2f}',
                   'FCFY': '{:.2f}%', 'PB' : '{:.2f}', 'ROE' : '{:.2f}', 'P/S (trail)': '{:.2f}',
                   'DPR': '{:.2f}%', 'DY': '{:.2f}%', 'CR' : '{:.2f}', 'Beta': '{:.2f}', '52w Low': '${:.2f}',
                   'Price': '${:.2f}', '52w High': '${:.2f}', '52w Range': '{:.2f}%'
                  })
    # Set the bar visualization
    styler.bar(subset = ['52w Range'], align = "mid", color = ["salmon", "cornflowerblue"])

    # Grid
    styler.set_properties(**{'border': '0.1px solid black'})

    # Set background gradients
    styler.background_gradient(subset=['EPS (fwd)'], cmap='Greens')
    styler.background_gradient(subset=['P/E (fwd)'], cmap='Greens')
    styler.background_gradient(subset=['PEG'], cmap='Greens')
    styler.background_gradient(subset=['FCFY'], cmap='Greens')
    styler.background_gradient(subset=['PB'], cmap='Greens')
    styler.background_gradient(subset=['ROE'], cmap='Greens')
    styler.background_gradient(subset=['P/S (trail)'], cmap='Greens')
    styler.background_gradient(subset=['DPR'], cmap='Greens')
    styler.background_gradient(subset=['DY'], cmap='Greens')
    styler.background_gradient(subset=['CR'], cmap='Greens')

    # No index
    styler.hide(axis='index')

    # Tooltips
    styler.set_tooltips(
        ttips, css_class='tt-add',
        props=[
            ('visibility', 'hidden'),
            ('position', 'absolute'),
            ('background-color', 'salmon'),
            ('color', 'black'),
            ('z-index', 1),
            ('padding', '3px 3px'),
            ('margin', '2px')
        ]
    )
    # Left text alignment for some columns
    styler.set_properties(subset=['Symbol', 'Name', 'Industry'], **{'text-align': 'left'})
    return styler

# %% [markdown]
# ## Adds Tool Tips

# %%
def populate_tt(df, tt_data, col_name):
    stats = df[col_name].describe()

    per25 = round(stats.loc['25%'], 2)
    per50 = round(stats.loc['50%'], 2)
    per75 = round(stats.loc['75%'], 2)

    # Get position based on the column name
    pos = df.columns.to_list().index(col_name)

    for index, row in df.iterrows():
        pe = row[col_name]
        if pe == stats.loc['min']:
            tt_data[index][pos] = 'Lowest'
        elif pe == stats.loc['max']:
            tt_data[index][pos] = 'Hightest'
        elif pe <= per25:
            tt_data[index][pos] = '25% of companies under {}'.format(per25)
        elif pe <= per50:
            tt_data[index][pos] = '50% of companies under {}'.format(per50)
        elif pe <= per75:
            tt_data[index][pos] = '75% of companies under {}'.format(per75)
        else:
            tt_data[index][pos] = '25% of companies over {}'.format(per75)

# %% [markdown]
# ## Apply styles and tooltips

# %%
# Initialize tool tip data - each column is set to '' for each row
tt_data = [['' for x in range(len(df.columns))] for y in range(len(df))]

# Gather tool tip data for indicators
populate_tt(df, tt_data, 'EPS (fwd)')
populate_tt(df, tt_data, 'P/E (fwd)')
populate_tt(df, tt_data, 'PEG')
populate_tt(df, tt_data, 'FCFY')
populate_tt(df, tt_data, 'PB')
populate_tt(df, tt_data, 'ROE')
populate_tt(df, tt_data, 'P/S (trail)')
populate_tt(df, tt_data, 'DPR')
populate_tt(df, tt_data, 'DY')
populate_tt(df, tt_data, 'CR')

# Create a tool tip DF
ttips = pd.DataFrame(data=tt_data, columns=df.columns, index=df.index)

# Add table caption and styles to DF
df.style.pipe(make_pretty).set_caption('Fundamental Indicators').set_table_styles(
    [{'selector': 'th.col_heading', 'props': 'text-align: center'},
     {'selector': 'caption', 'props': [('text-align', 'center'),
                                       ('font-size', '11pt'), ('font-weight', 'bold')]}])
# Out:
# <style type="text/css">
# #T_6cd1d th.col_heading {
#   text-align: center;
# }
# #T_6cd1d caption {
#   text-align: center;
#   font-size: 11pt;
#   font-weight: bold;
# }
# #T_6cd1d .tt-add {
#   visibility: hidden;
#   position: absolute;
#   background-color: salmon;
#   color: black;
#   z-index: 1;
#   padding: 3px 3px;
#   margin: 2px;
# }
# #T_6cd1d #T_6cd1d_row0_col3:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row0_col3 .tt-add::after {
#   content: "Hightest";
# }
# #T_6cd1d #T_6cd1d_row0_col4:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row0_col4 .tt-add::after {
#   content: "75% of companies under 48.22";
# }
# #T_6cd1d #T_6cd1d_row0_col5:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row0_col5 .tt-add::after {
#   content: "75% of companies under 3.89";
# }
# #T_6cd1d #T_6cd1d_row0_col6:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row0_col6 .tt-add::after {
#   content: "50% of companies under 2.8";
# }
# #T_6cd1d #T_6cd1d_row0_col7:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row0_col7 .tt-add::after {
#   content: "75% of companies under 22.67";
# }
# #T_6cd1d #T_6cd1d_row0_col8:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row0_col8 .tt-add::after {
#   content: "25% of companies over 0.14";
# }
# #T_6cd1d #T_6cd1d_row0_col9:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row0_col9 .tt-add::after {
#   content: "75% of companies under 13.23";
# }
# #T_6cd1d #T_6cd1d_row0_col10:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row0_col10 .tt-add::after {
#   content: "Hightest";
# }
# #T_6cd1d #T_6cd1d_row0_col11:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row0_col11 .tt-add::after {
#   content: "25% of companies over 0.0";
# }
# #T_6cd1d #T_6cd1d_row0_col12:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row0_col12 .tt-add::after {
#   content: "50% of companies under 1.47";
# }
# #T_6cd1d #T_6cd1d_row1_col3:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row1_col3 .tt-add::after {
#   content: "75% of companies under 7.96";
# }
# #T_6cd1d #T_6cd1d_row1_col4:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row1_col4 .tt-add::after {
#   content: "25% of companies over 48.22";
# }
# #T_6cd1d #T_6cd1d_row1_col5:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row1_col5 .tt-add::after {
#   content: "75% of companies under 3.89";
# }
# #T_6cd1d #T_6cd1d_row1_col6:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row1_col6 .tt-add::after {
#   content: "Lowest";
# }
# #T_6cd1d #T_6cd1d_row1_col7:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row1_col7 .tt-add::after {
#   content: "25% of companies over 22.67";
# }
# #T_6cd1d #T_6cd1d_row1_col8:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row1_col8 .tt-add::after {
#   content: "25% of companies over 0.14";
# }
# #T_6cd1d #T_6cd1d_row1_col9:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row1_col9 .tt-add::after {
#   content: "Hightest";
# }
# #T_6cd1d #T_6cd1d_row1_col10:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row1_col10 .tt-add::after {
#   content: "Lowest";
# }
# #T_6cd1d #T_6cd1d_row1_col11:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row1_col11 .tt-add::after {
#   content: "Lowest";
# }
# #T_6cd1d #T_6cd1d_row1_col12:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row1_col12 .tt-add::after {
#   content: "50% of companies under 1.47";
# }
# #T_6cd1d #T_6cd1d_row2_col3:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row2_col3 .tt-add::after {
#   content: "75% of companies under 7.96";
# }
# #T_6cd1d #T_6cd1d_row2_col4:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row2_col4 .tt-add::after {
#   content: "75% of companies under 48.22";
# }
# #T_6cd1d #T_6cd1d_row2_col5:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row2_col5 .tt-add::after {
#   content: "25% of companies under 1.78";
# }
# #T_6cd1d #T_6cd1d_row2_col6:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row2_col6 .tt-add::after {
#   content: "50% of companies under 2.8";
# }
# #T_6cd1d #T_6cd1d_row2_col7:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row2_col7 .tt-add::after {
#   content: "75% of companies under 22.67";
# }
# #T_6cd1d #T_6cd1d_row2_col8:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row2_col8 .tt-add::after {
#   content: "25% of companies under 0.02";
# }
# #T_6cd1d #T_6cd1d_row2_col9:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row2_col9 .tt-add::after {
#   content: "75% of companies under 13.23";
# }
# #T_6cd1d #T_6cd1d_row2_col10:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row2_col10 .tt-add::after {
#   content: "Lowest";
# }
# #T_6cd1d #T_6cd1d_row2_col11:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row2_col11 .tt-add::after {
#   content: "Lowest";
# }
# #T_6cd1d #T_6cd1d_row2_col12:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row2_col12 .tt-add::after {
#   content: "75% of companies under 2.39";
# }
# #T_6cd1d #T_6cd1d_row3_col3:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row3_col3 .tt-add::after {
#   content: "25% of companies over 7.96";
# }
# #T_6cd1d #T_6cd1d_row3_col4:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row3_col4 .tt-add::after {
#   content: "50% of companies under 30.5";
# }
# #T_6cd1d #T_6cd1d_row3_col5:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row3_col5 .tt-add::after {
#   content: "75% of companies under 3.89";
# }
# #T_6cd1d #T_6cd1d_row3_col6:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row3_col6 .tt-add::after {
#   content: "25% of companies over 4.67";
# }
# #T_6cd1d #T_6cd1d_row3_col7:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row3_col7 .tt-add::after {
#   content: "50% of companies under 9.32";
# }
# #T_6cd1d #T_6cd1d_row3_col8:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row3_col8 .tt-add::after {
#   content: "50% of companies under 0.09";
# }
# #T_6cd1d #T_6cd1d_row3_col9:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row3_col9 .tt-add::after {
#   content: "50% of companies under 10.63";
# }
# #T_6cd1d #T_6cd1d_row3_col10:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row3_col10 .tt-add::after {
#   content: "25% of companies over 0.0";
# }
# #T_6cd1d #T_6cd1d_row3_col11:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row3_col11 .tt-add::after {
#   content: "25% of companies over 0.0";
# }
# #T_6cd1d #T_6cd1d_row3_col12:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row3_col12 .tt-add::after {
#   content: "Lowest";
# }
# #T_6cd1d #T_6cd1d_row4_col3:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row4_col3 .tt-add::after {
#   content: "50% of companies under 5.51";
# }
# #T_6cd1d #T_6cd1d_row4_col4:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row4_col4 .tt-add::after {
#   content: "Hightest";
# }
# #T_6cd1d #T_6cd1d_row4_col5:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row4_col5 .tt-add::after {
#   content: "25% of companies over 3.89";
# }
# #T_6cd1d #T_6cd1d_row4_col6:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row4_col6 .tt-add::after {
#   content: "25% of companies under 1.78";
# }
# #T_6cd1d #T_6cd1d_row4_col7:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row4_col7 .tt-add::after {
#   content: "Hightest";
# }
# #T_6cd1d #T_6cd1d_row4_col8:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row4_col8 .tt-add::after {
#   content: "Lowest";
# }
# #T_6cd1d #T_6cd1d_row4_col9:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row4_col9 .tt-add::after {
#   content: "25% of companies over 13.23";
# }
# #T_6cd1d #T_6cd1d_row4_col10:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row4_col10 .tt-add::after {
#   content: "Lowest";
# }
# #T_6cd1d #T_6cd1d_row4_col11:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row4_col11 .tt-add::after {
#   content: "Lowest";
# }
# #T_6cd1d #T_6cd1d_row4_col12:hover .tt-add {
#   visibility: visible;
# }
# #T_6cd1d #T_6cd1d_row4_col12 .tt-add::after {
#   content: "50% of companies under 1.47";
# }
# #T_6cd1d #T_6cd1d_row5_col3:hover .tt-add {

# %% [markdown]
# ## Description
# 1. __[EPS](https://www.investopedia.com/terms/e/eps.asp)__ (Earnings Per Share): portion of a company’s profit that is assigned to each share of its stock
# 2. __[P/E](https://www.investopedia.com/terms/p/price-earningsratio.asp)__ (Price to Earnings): relationship between the stock price of a company and its per-share earnings. It helps investors determine if a stock is undervalued or overvalued relative to others in the same sector.
# 3. __[PEG](https://www.investopedia.com/terms/p/pegratio.asp)}__ (Projected Earnings Growth): - calculated by dividing a stock’s P/E by its projected 12-month forward revenue growth rate. In general, a PEG lower than 1 is a good sign, and a PEG higher than 2 indicates that a stock may be overpriced
# 4. __[FCFY](https://www.investopedia.com/articles/fundamental-analysis/09/free-cash-flow-yield.asp)__ (Free Cash Flow Yield): a financial solvency ratio that compares the free cash flow per share a company is expected to earn against its market value per share. A lower ratio indicates a less attractive investment opportunity.
# 5. __[PB](https://www.investopedia.com/terms/p/price-to-bookratio.asp)__ (Price to Book): A ratio of 1 indicates the company's shares are trading in line with its book value. A P/B higher than 1 suggests the company is trading at a premium to book value, and lower than 1 indicates a stock that may be undervalued relative to the company's assets.
# 6. __[ROE](https://www.investopedia.com/terms/r/returnonequity.asp)__ (Return on Equity): provides a way for investors to evaluate how effectively a company is using its equity to generate profits. A higher ROE indicates a more efficient use of shareholder equity, which can lead to increased demand for shares and higher stock price, as well as increase in company's profits in the future.
# 7. __[P/S](https://www.investopedia.com/terms/p/price-to-salesratio.asp)__ (Price to Sales): determines the fair value of a stock by utilizing a company’s market capitalization and revenue. It shows how much the market values the company’s sales, which can be effective in valuing growth stocks that have yet to turn a profit or aren’t performing as expected due to a temporary setback.
# 8. __[DPR](https://www.investopedia.com/terms/d/dividendpayoutratio.asp)__ (Dividend Payment Ratio): ratio of the total amount of dividends paid out to shareholders relative to the net income of the company. _Reference:_ __[Dividend Payout Ratio Definition, Formula, and Calculation](https://www.investopedia.com/terms/d/dividendpayoutratio.asp)__
# 9. __[DY](https://www.investopedia.com/terms/d/dividendyield.asp)__ (Dividend Yield Ratio): ratio looks at the amount paid by a company in dividends every year relative to its share price. It is an estimate of the dividend-only return of a stock investment.
# 10. __[CR](https://www.investopedia.com/terms/c/currentratio.asp)__ (Current Ratio): measures a company's ability to pay off its current liabilities (payable within one year) with its current assets such as cash, accounts receivable, and inventories. The higher the ratio, the better the company's liquidity position.
# 11. __[Beta](https://www.investopedia.com/terms/b/beta.asp)__: is a measure of a stock's volatility in relation to the overall market. A stock that swings more than the market over time has a beta above 1.0. If a stock moves less than the market, the stock's beta is less than 1.0.
# 12. __52w Range__: a visualization to indicate which stocks are near their 52 week low and which are near their 52 week high. For example, 90% will indicate that the current price is very close to its 52 week high
#
# ### Reference:
# 1. __[Top 10 Fundamental Analysis Indicators for All Investors](https://investoracademy.org/top-10-fundamental-analysis-indicators-for-all-investors/)__
# 2. __[Five Key Financial Ratios for Stock Analysis](https://www.schwab.com/learn/story/five-key-financial-ratios-stock-analysis#:~:text=Learn%20how%20these%20five%20key,depth%20of%20perspective%20you%20need)__
